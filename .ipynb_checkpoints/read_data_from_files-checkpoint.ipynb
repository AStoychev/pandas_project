# %%
import pandas as pd

# %%
df = pd.read_csv('pandas_data_from_file.csv')

# %%
df
# Out:
#    first name;last name;experience;score
# 0                   Alex;Jones;Python;92
# 1                     James;Jones;C++;97
# 2                Mary;Williams;Python;98
# 3                 Patricia;Brown;Java;87
# 4                Jennifer;Taylor;HTML;88
# 5                Emily;Davies;Android;90
# 6               Michael;Wilson;Python;91
# 7                   Jessica;Evans;C++;95
# 8                  John;Thomas;Python;90
# 9                 Thomas;Roberts;Java;89
# 10          Christopher;Marton;Python;83
# 11                    Barbara;Lee;C++;86
# 12                 Matthew;Anderson;R;97
# 13                  Mark;White;Python;91
# 14                  Nancy;Taylor;Java;96
# 15                     Andrew;Smith;R;92

# %%
df2 = pd.read_csv('pandas_data_from_file_2.csv')

# %%
df2
# Out:
#    first name;last name;experience;score
# 0                   Alex;Jones;Python;92
# 1                     James;Jones;C++;97
# 2                Mary;Williams;Python;98
# 3                 Patricia;Brown;Java;87
# 4                Jennifer;Taylor;HTML;88
# 5                Emily;Davies;Android;90
# 6               Michael;Wilson;Python;91
# 7                   Jessica;Evans;C++;95
# 8                  John;Thomas;Python;90
# 9                 Thomas;Roberts;Java;89
# 10          Christopher;Marton;Python;83
# 11                    Barbara;Lee;C++;86
# 12                 Matthew;Anderson;R;97
# 13                  Mark;White;Python;91
# 14                  Nancy;Taylor;Java;96
# 15                     Andrew;Smith;R;92

# %%
df2
# Out:
#    first name;last name;experience;score
# 0                   Alex;Jones;Python;92
# 1                     James;Jones;C++;97
# 2                Mary;Williams;Python;98
# 3                 Patricia;Brown;Java;87
# 4                Jennifer;Taylor;HTML;88
# 5                Emily;Davies;Android;90
# 6               Michael;Wilson;Python;91
# 7                   Jessica;Evans;C++;95
# 8                  John;Thomas;Python;90
# 9                 Thomas;Roberts;Java;89
# 10          Christopher;Marton;Python;83
# 11                    Barbara;Lee;C++;86
# 12                 Matthew;Anderson;R;97
# 13                  Mark;White;Python;91
# 14                  Nancy;Taylor;Java;96
# 15                     Andrew;Smith;R;92

# %%
df2 = pd.read_csv('pandas_data_from_file_2.csv')

# %%
df2
# Out:
#             Alex;Jones;Python;92
# 0             James;Jones;C++;97
# 1        Mary;Williams;Python;98
# 2         Patricia;Brown;Java;87
# 3        Jennifer;Taylor;HTML;88
# 4        Emily;Davies;Android;90
# 5       Michael;Wilson;Python;91
# 6           Jessica;Evans;C++;95
# 7          John;Thomas;Python;90
# 8         Thomas;Roberts;Java;89
# 9   Christopher;Marton;Python;83
# 10            Barbara;Lee;C++;86
# 11         Matthew;Anderson;R;97
# 12          Mark;White;Python;91
# 13          Nancy;Taylor;Java;96
# 14             Andrew;Smith;R;92

# %%
df2 = pd.read_csv('pandas_data_from_file_2.csv', header=None)

# %%
df2
# Out:
#                                0
# 0           Alex;Jones;Python;92
# 1             James;Jones;C++;97
# 2        Mary;Williams;Python;98
# 3         Patricia;Brown;Java;87
# 4        Jennifer;Taylor;HTML;88
# 5        Emily;Davies;Android;90
# 6       Michael;Wilson;Python;91
# 7           Jessica;Evans;C++;95
# 8          John;Thomas;Python;90
# 9         Thomas;Roberts;Java;89
# 10  Christopher;Marton;Python;83
# 11            Barbara;Lee;C++;86
# 12         Matthew;Anderson;R;97
# 13          Mark;White;Python;91
# 14          Nancy;Taylor;Java;96
# 15             Andrew;Smith;R;92

# %%
df2 = pd.read_csv('table.txt', header=None)

# %%
df2
# Out:
#               0         1        2     3
# 0          Alex     Jones   Python  92.0
# 1         James     Jones      C++  97.0
# 2          Mary  Williams   Python  98.0
# 3      Patricia     Brown     Java  87.0
# 4      Jennifer    Taylor     HTML  88.0
# 5         Emily    Davies  Android  90.0
# 6       Michael    Wilson   Python  91.0
# 7       Jessica     Evans      C++  95.0
# 8          John    Thomas   Python  90.0
# 9        Thomas   Roberts     Java  89.0
# 10  Christopher    Marton   Python  83.0
# 11      Barbara       Lee  C++\t86   NaN
# 12      Matthew  Anderson        R  97.0
# 13         Mark     White   Python  91.0
# 14        Nancy    Taylor     Java  96.0
# 15       Andrew     Smith        R  92.0

# %%
df2 = pd.read_csv('table.txt', header=None,names = ['fname','lname','course','score'])

# %%
df2
# Out:
#           fname     lname   course  score
# 0          Alex     Jones   Python   92.0
# 1         James     Jones      C++   97.0
# 2          Mary  Williams   Python   98.0
# 3      Patricia     Brown     Java   87.0
# 4      Jennifer    Taylor     HTML   88.0
# 5         Emily    Davies  Android   90.0
# 6       Michael    Wilson   Python   91.0
# 7       Jessica     Evans      C++   95.0
# 8          John    Thomas   Python   90.0
# 9        Thomas   Roberts     Java   89.0
# 10  Christopher    Marton   Python   83.0
# 11      Barbara       Lee  C++\t86    NaN
# 12      Matthew  Anderson        R   97.0
# 13         Mark     White   Python   91.0
# 14        Nancy    Taylor     Java   96.0
# 15       Andrew     Smith        R   92.0

# %%
df1= pd.read_csv('pandas_data_from_file.csv',skiprows=1,names = ['a','b','c','d'])

# %%
df1
# Out:
#                                a   b   c   d
# 0           Alex;Jones;Python;92 NaN NaN NaN
# 1             James;Jones;C++;97 NaN NaN NaN
# 2        Mary;Williams;Python;98 NaN NaN NaN
# 3         Patricia;Brown;Java;87 NaN NaN NaN
# 4        Jennifer;Taylor;HTML;88 NaN NaN NaN
# 5        Emily;Davies;Android;90 NaN NaN NaN
# 6       Michael;Wilson;Python;91 NaN NaN NaN
# 7           Jessica;Evans;C++;95 NaN NaN NaN
# 8          John;Thomas;Python;90 NaN NaN NaN
# 9         Thomas;Roberts;Java;89 NaN NaN NaN
# 10  Christopher;Marton;Python;83 NaN NaN NaN
# 11            Barbara;Lee;C++;86 NaN NaN NaN
# 12         Matthew;Anderson;R;97 NaN NaN NaN
# 13          Mark;White;Python;91 NaN NaN NaN
# 14          Nancy;Taylor;Java;96 NaN NaN NaN
# 15             Andrew;Smith;R;92 NaN NaN NaN

# %%
df1= pd.read_csv('table_data_from_file.txt',skiprows=1,names = ['a','b','c','d'])

# %%
df1
# Out:
#               a         b        c     d
# 0          Alex     Jones   Python  92.0
# 1         James     Jones      C++  97.0
# 2          Mary  Williams   Python  98.0
# 3      Patricia     Brown     Java  87.0
# 4      Jennifer    Taylor     HTML  88.0
# 5         Emily    Davies  Android  90.0
# 6       Michael    Wilson   Python  91.0
# 7       Jessica     Evans      C++  95.0
# 8          John    Thomas   Python  90.0
# 9        Thomas   Roberts     Java  89.0
# 10  Christopher    Marton   Python  83.0
# 11      Barbara       Lee  C++\t86   NaN
# 12      Matthew  Anderson        R  97.0
# 13         Mark     White   Python  91.0
# 14        Nancy    Taylor     Java  96.0
# 15       Andrew     Smith        R  92.0

# %%
df1= pd.read_csv('pandas_data_from_file.csv')

# %%
df3 = pd.read_csv('pandas_data_from_file.csv')

# %%
df3
# Out:
#    first name;last name;experience;score
# 0                   Alex;Jones;Python;92
# 1                     James;Jones;C++;97
# 2                Mary;Williams;Python;98
# 3                 Patricia;Brown;Java;87
# 4                Jennifer;Taylor;HTML;88
# 5                Emily;Davies;Android;90
# 6               Michael;Wilson;Python;91
# 7                   Jessica;Evans;C++;95
# 8                  John;Thomas;Python;90
# 9                 Thomas;Roberts;Java;89
# 10          Christopher;Marton;Python;83
# 11                    Barbara;Lee;C++;86
# 12                 Matthew;Anderson;R;97
# 13                  Mark;White;Python;91
# 14                  Nancy;Taylor;Java;96
# 15                     Andrew;Smith;R;92

# %%
len(df3.columns)
# Out:
# 1

# %%
df3 = pd.read_csv('pandas_data_from_file.csv',sep = ';')

# %%
df3
# Out:
#      first name last name experience  score
# 0          Alex     Jones     Python     92
# 1         James     Jones        C++     97
# 2          Mary  Williams     Python     98
# 3      Patricia     Brown       Java     87
# 4      Jennifer    Taylor       HTML     88
# 5         Emily    Davies    Android     90
# 6       Michael    Wilson     Python     91
# 7       Jessica     Evans        C++     95
# 8          John    Thomas     Python     90
# 9        Thomas   Roberts       Java     89
# 10  Christopher    Marton     Python     83
# 11      Barbara       Lee        C++     86
# 12      Matthew  Anderson          R     97
# 13         Mark     White     Python     91
# 14        Nancy    Taylor       Java     96
# 15       Andrew     Smith          R     92

# %%
df4 = pd.read_csv('table_data_from_file_with_description.txt')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df4 = pd.read_csv('table_data_from_file_with_description.txt')
#
# File ~\Desktop\jupyter\venv\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
# ...

# %%
df4= pd.read_csv('table_data_from_file_with_description.txt')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df4= pd.read_csv('table_data_from_file_with_description.txt')
#
# File ~\Desktop\jupyter\venv\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
# ...

# %%
df4 = pd.read_csv('table_data_from_file_with_description.xlsx')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df4 = pd.read_csv('table_data_from_file_with_description.xlsx')
#
# File ~\Desktop\jupyter\venv\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
# ...

# %%
df4 = pd.read_csv('with_description.txt')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df4 = pd.read_csv('with_description.txt')
#
# File ~\Desktop\jupyter\venv\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
# ...

# %%
df4 = pd.read_csv('table_data_from_file_with_description.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df4 = pd.read_csv('table_data_from_file_with_description.txt')
#
# File ~\Desktop\jupyter\venv\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
# ...

# %%
df = pd.read_csv('pandas_data_from_file.csv')

# %%
df4 = pd.read_csv('table_data_from_file_2.txt')

# %%
df4
# Out:
#            Alex     Jones   Python    92
# 0         James     Jones      C++  97.0
# 1          Mary  Williams   Python  98.0
# 2      Patricia     Brown     Java  87.0
# 3      Jennifer    Taylor     HTML  88.0
# 4         Emily    Davies  Android  90.0
# 5       Michael    Wilson   Python  91.0
# 6       Jessica     Evans      C++  95.0
# 7          John    Thomas   Python  90.0
# 8        Thomas   Roberts     Java  89.0
# 9   Christopher    Marton   Python  83.0
# 10      Barbara       Lee  C++\t86   NaN
# 11      Matthew  Anderson        R  97.0
# 12         Mark     White   Python  91.0
# 13        Nancy    Taylor     Java  96.0
# 14       Andrew     Smith        R  92.0

# %%
df4 = pd.read_csv('with_description.txt')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df4 = pd.read_csv('with_description.txt')
#
# File ~\Desktop\jupyter\venv\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
# ...

# %%
df4 = pd.read_csv('table_data_from_file_with_description.csv')

# %%
df4
# Out:
#               # This is the dataset description;;;
# 0     # These lines are not part of dataset and;;;
# 1   # should be ignore when reading the dataset;;;
# 2            first name;last name;experience;score
# 3                             Alex;Jones;Python;92
# 4                               James;Jones;C++;97
# 5                          Mary;Williams;Python;98
# 6                           Patricia;Brown;Java;87
# 7                          Jennifer;Taylor;HTML;88
# 8                          Emily;Davies;Android;90
# 9                         Michael;Wilson;Python;91
# 10                            Jessica;Evans;C++;95
# 11                           John;Thomas;Python;90
# 12                          Thomas;Roberts;Java;89
# 13                    Christopher;Marton;Python;83
# 14                              Barbara;Lee;C++;86
# 15                           Matthew;Anderson;R;97
# 16                            Mark;White;Python;91
# ...

# %%
df4 = pd.read_csv('table_data_from_file_with_description.csv',comment='#')

# %%
df4
# Out:
#    first name;last name;experience;score
# 0                   Alex;Jones;Python;92
# 1                     James;Jones;C++;97
# 2                Mary;Williams;Python;98
# 3                 Patricia;Brown;Java;87
# 4                Jennifer;Taylor;HTML;88
# 5                Emily;Davies;Android;90
# 6               Michael;Wilson;Python;91
# 7                   Jessica;Evans;C++;95
# 8                  John;Thomas;Python;90
# 9                 Thomas;Roberts;Java;89
# 10          Christopher;Marton;Python;83
# 11                    Barbara;Lee;C++;86
# 12                 Matthew;Anderson;R;97
# 13                  Mark;White;Python;91
# 14                  Nancy;Taylor;Java;96
# 15                     Andrew;Smith;R;92

# %%
df4 = pd.read_csv('table_data_from_file_with_description.csv',comment='#',sep = ';')

# %%
df4
# Out:
#      first name last name experience  score
# 0          Alex     Jones     Python     92
# 1         James     Jones        C++     97
# 2          Mary  Williams     Python     98
# 3      Patricia     Brown       Java     87
# 4      Jennifer    Taylor       HTML     88
# 5         Emily    Davies    Android     90
# 6       Michael    Wilson     Python     91
# 7       Jessica     Evans        C++     95
# 8          John    Thomas     Python     90
# 9        Thomas   Roberts       Java     89
# 10  Christopher    Marton     Python     83
# 11      Barbara       Lee        C++     86
# 12      Matthew  Anderson          R     97
# 13         Mark     White     Python     91
# 14        Nancy    Taylor       Java     96
# 15       Andrew     Smith          R     92

# %%
df4 = pd.read_csv('table_data_description.csv')

# %%
df4
# Out:
#               This is the dataset description;;;
# 0     These lines are not part of dataset and;;;
# 1   should be ignore when reading the dataset;;;
# 2          first name;last name;experience;score
# 3                           Alex;Jones;Python;92
# 4                             James;Jones;C++;97
# 5                        Mary;Williams;Python;98
# 6                         Patricia;Brown;Java;87
# 7                        Jennifer;Taylor;HTML;88
# 8                        Emily;Davies;Android;90
# 9                       Michael;Wilson;Python;91
# 10                          Jessica;Evans;C++;95
# 11                         John;Thomas;Python;90
# 12                        Thomas;Roberts;Java;89
# 13                  Christopher;Marton;Python;83
# 14                            Barbara;Lee;C++;86
# 15                         Matthew;Anderson;R;97
# 16                          Mark;White;Python;91
# 17                          Nancy;Taylor;Java;96
# ...

# %%
df5 = pd.read_csv('table_data_from_file_with_description.csv')

# %%
df5
# Out:
#               # This is the dataset description;;;
# 0     # These lines are not part of dataset and;;;
# 1   # should be ignore when reading the dataset;;;
# 2            first name;last name;experience;score
# 3                             Alex;Jones;Python;92
# 4                               James;Jones;C++;97
# 5                          Mary;Williams;Python;98
# 6                           Patricia;Brown;Java;87
# 7                          Jennifer;Taylor;HTML;88
# 8                          Emily;Davies;Android;90
# 9                         Michael;Wilson;Python;91
# 10                            Jessica;Evans;C++;95
# 11                           John;Thomas;Python;90
# 12                          Thomas;Roberts;Java;89
# 13                    Christopher;Marton;Python;83
# 14                              Barbara;Lee;C++;86
# 15                           Matthew;Anderson;R;97
# 16                            Mark;White;Python;91
# ...

# %%
df5 = pd.read_csv('table_data_description.csv')

# %%
df5
# Out:
#               This is the dataset description;;;
# 0     These lines are not part of dataset and;;;
# 1   should be ignore when reading the dataset;;;
# 2          first name;last name;experience;score
# 3                           Alex;Jones;Python;92
# 4                             James;Jones;C++;97
# 5                        Mary;Williams;Python;98
# 6                         Patricia;Brown;Java;87
# 7                        Jennifer;Taylor;HTML;88
# 8                        Emily;Davies;Android;90
# 9                       Michael;Wilson;Python;91
# 10                          Jessica;Evans;C++;95
# 11                         John;Thomas;Python;90
# 12                        Thomas;Roberts;Java;89
# 13                  Christopher;Marton;Python;83
# 14                            Barbara;Lee;C++;86
# 15                         Matthew;Anderson;R;97
# 16                          Mark;White;Python;91
# 17                          Nancy;Taylor;Java;96
# ...

# %%
df5 = pd.read_csv('table_data_description.csv',skiprows=3)

# %%
df5
# Out:
#    first name;last name;experience;score
# 0                   Alex;Jones;Python;92
# 1                     James;Jones;C++;97
# 2                Mary;Williams;Python;98
# 3                 Patricia;Brown;Java;87
# 4                Jennifer;Taylor;HTML;88
# 5                Emily;Davies;Android;90
# 6               Michael;Wilson;Python;91
# 7                   Jessica;Evans;C++;95
# 8                  John;Thomas;Python;90
# 9                 Thomas;Roberts;Java;89
# 10          Christopher;Marton;Python;83
# 11                    Barbara;Lee;C++;86
# 12                 Matthew;Anderson;R;97
# 13                  Mark;White;Python;91
# 14                  Nancy;Taylor;Java;96
# 15                     Andrew;Smith;R;92

# %%
df5 = pd.read_csv('table_data_description.csv',sep=';')

# %%
df5
# Out:
#               This is the dataset description Unnamed: 1  Unnamed: 2  \
# 0     These lines are not part of dataset and        NaN         NaN
# 1   should be ignore when reading the dataset        NaN         NaN
# 2                                  first name  last name  experience
# 3                                        Alex      Jones      Python
# 4                                       James      Jones         C++
# 5                                        Mary   Williams      Python
# 6                                    Patricia      Brown        Java
# 7                                    Jennifer     Taylor        HTML
# 8                                       Emily     Davies     Android
# 9                                     Michael     Wilson      Python
# 10                                    Jessica      Evans         C++
# 11                                       John     Thomas      Python
# 12                                     Thomas    Roberts        Java
# ...

# %%
df5 = pd.read_csv('table_data_description.csv',skiprows=3,sep=';')

# %%
df5
# Out:
#      first name last name experience  score
# 0          Alex     Jones     Python     92
# 1         James     Jones        C++     97
# 2          Mary  Williams     Python     98
# 3      Patricia     Brown       Java     87
# 4      Jennifer    Taylor       HTML     88
# 5         Emily    Davies    Android     90
# 6       Michael    Wilson     Python     91
# 7       Jessica     Evans        C++     95
# 8          John    Thomas     Python     90
# 9        Thomas   Roberts       Java     89
# 10  Christopher    Marton     Python     83
# 11      Barbara       Lee        C++     86
# 12      Matthew  Anderson          R     97
# 13         Mark     White     Python     91
# 14        Nancy    Taylor       Java     96
# 15       Andrew     Smith          R     92
