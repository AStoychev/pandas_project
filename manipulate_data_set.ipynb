# %%
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')

# %%
df.shape
# Out:
# (891, 12)

# %%
df.head
# Out:
# <bound method NDFrame.head of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.Sex
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
df.rename({'PassengerId':'Passenger_Id', 'Survived', 'Pclass', 'Name':'First_Name', 'Age', 'SibSp':'Sib_Sp',
       'Parch', 'Fare', 'Cabin', 'Embarked'},axis=1)
# Out:
#   Cell In[8], line 1
#     df.rename({'PassengerId':'Passenger_Id', 'Survived', 'Pclass', 'Name':'First_Name', 'Age', 'SibSp':'Sib_Sp',
#                                                       ^
# SyntaxError: ':' expected after dictionary key

# %%
df.rename({'PassengerId':'Passenger_Id', 'Pclass', 'Name':'First_Name', 'Age', 'SibSp':'Sib_Sp',
       'Parch', 'Fare', 'Cabin', 'Embarked'},axis=1)
# Out:
#   Cell In[9], line 1
#     df.rename({'PassengerId':'Passenger_Id', 'Pclass', 'Name':'First_Name', 'Age', 'SibSp':'Sib_Sp',
#                                                     ^
# SyntaxError: ':' expected after dictionary key

# %%
df.rename({'PassengerId':'Passenger_Id', 'Pclass':'P_Class', 'Name':'First_Name', 'SibSp':'Sib_Sp',},axis=1)
# Out:
#      Passenger_Id  Survived  P_Class  \
# 0               1         0        3
# 1               2         1        1
# 2               3         1        3
# 3               4         1        1
# 4               5         0        3
# ..            ...       ...      ...
# 886           887         0        2
# 887           888         1        1
# 888           889         0        3
# 889           890         1        1
# 890           891         0        3
#
#                                             First_Name     Sex   Age  Sib_Sp  \
# 0                              Braund, Mr. Owen Harris    male  22.0       1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0       1
# 2                               Heikkinen, Miss. Laina  female  26.0       0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0       1
# 4                             Allen, Mr. William Henry    male  35.0       0
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.rename({'PassengerId':'Passenger_Id', 'Pclass':'P_Class', 'Name':'First_Name', 'SibSp':'Sib_Sp',},axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Passenger_Id', 'Survived', 'P_Class', 'First_Name', 'Sex', 'Age',
#        'Sib_Sp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df
# Out:
#      Passenger_Id  Survived  P_Class  \
# 0               1         0        3
# 1               2         1        1
# 2               3         1        3
# 3               4         1        1
# 4               5         0        3
# ..            ...       ...      ...
# 886           887         0        2
# 887           888         1        1
# 888           889         0        3
# 889           890         1        1
# 890           891         0        3
#
#                                             First_Name     Sex   Age  Sib_Sp  \
# 0                              Braund, Mr. Owen Harris    male  22.0       1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0       1
# 2                               Heikkinen, Miss. Laina  female  26.0       0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0       1
# 4                             Allen, Mr. William Henry    male  35.0       0
# ...

# %%
df.Bonus.round()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.Bonus.round()
#
# File ~\Desktop\jupyter\venv\lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Bonus'

# %%
df.Fare.round()
# Out:
# 0       7.0
# 1      71.0
# 2       8.0
# 3      53.0
# 4       8.0
#        ...
# 886    13.0
# 887    30.0
# 888    23.0
# 889    30.0
# 890     8.0
# Name: Fare, Length: 891, dtype: float64

# %%
df['Fare2] = df.Fare.round()
# Out:
#   Cell In[17], line 1
#     df['Fare2] = df.Fare.round()
#        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
df['Fare2']= df.Fare.round()

# %%
df
# Out:
#      Passenger_Id  Survived  P_Class  \
# 0               1         0        3
# 1               2         1        1
# 2               3         1        3
# 3               4         1        1
# 4               5         0        3
# ..            ...       ...      ...
# 886           887         0        2
# 887           888         1        1
# 888           889         0        3
# 889           890         1        1
# 890           891         0        3
#
#                                             First_Name     Sex   Age  Sib_Sp  \
# 0                              Braund, Mr. Owen Harris    male  22.0       1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0       1
# 2                               Heikkinen, Miss. Laina  female  26.0       0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0       1
# 4                             Allen, Mr. William Henry    male  35.0       0
# ...

# %%
import numpy as np

# %%
pd.Series(np.random.randint(0,10,891)
# Out:
#   Cell In[21], line 1
#     pd.Series(np.random.randint(0,10,891)
#              ^
# SyntaxError: '(' was never closed

# %%
pd.Series(np.random.randint(0,10,891))
# Out:
# 0      9
# 1      6
# 2      2
# 3      9
# 4      5
#       ..
# 886    4
# 887    2
# 888    5
# 889    1
# 890    4
# Length: 891, dtype: int32

# %%
df['random'] = pd.Series(np.random.randint(0,10,891))

# %%
df
# Out:
#      Passenger_Id  Survived  P_Class  \
# 0               1         0        3
# 1               2         1        1
# 2               3         1        3
# 3               4         1        1
# 4               5         0        3
# ..            ...       ...      ...
# 886           887         0        2
# 887           888         1        1
# 888           889         0        3
# 889           890         1        1
# 890           891         0        3
#
#                                             First_Name     Sex   Age  Sib_Sp  \
# 0                              Braund, Mr. Owen Harris    male  22.0       1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0       1
# 2                               Heikkinen, Miss. Laina  female  26.0       0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0       1
# 4                             Allen, Mr. William Henry    male  35.0       0
# ...

# %%
df2 = df.iloc[:2]

# %%
df2
# Out:
#    Passenger_Id  Survived  P_Class  \
# 0             1         0        3
# 1             2         1        1
#
#                                           First_Name     Sex   Age  Sib_Sp  \
# 0                            Braund, Mr. Owen Harris    male  22.0       1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0       1
#
#    Parch     Ticket     Fare Cabin Embarked  Fare2  random
# 0      0  A/5 21171   7.2500   NaN        S    7.0       8
# 1      0   PC 17599  71.2833   C85        C   71.0       7

# %%
df3 = pd.concat((df,df2),axis = 0)

# %%
df3
# Out:
#      Passenger_Id  Survived  P_Class  \
# 0               1         0        3
# 1               2         1        1
# 2               3         1        3
# 3               4         1        1
# 4               5         0        3
# ..            ...       ...      ...
# 888           889         0        3
# 889           890         1        1
# 890           891         0        3
# 0               1         0        3
# 1               2         1        1
#
#                                             First_Name     Sex   Age  Sib_Sp  \
# 0                              Braund, Mr. Owen Harris    male  22.0       1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0       1
# 2                               Heikkinen, Miss. Laina  female  26.0       0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0       1
# 4                             Allen, Mr. William Henry    male  35.0       0
# ...

# %%
df3 = pd.concat((df,df2),axis = 0,ignore_index=True)

# %%
df3
# Out:
#      Passenger_Id  Survived  P_Class  \
# 0               1         0        3
# 1               2         1        1
# 2               3         1        3
# 3               4         1        1
# 4               5         0        3
# ..            ...       ...      ...
# 888           889         0        3
# 889           890         1        1
# 890           891         0        3
# 891             1         0        3
# 892             2         1        1
#
#                                             First_Name     Sex   Age  Sib_Sp  \
# 0                              Braund, Mr. Owen Harris    male  22.0       1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0       1
# 2                               Heikkinen, Miss. Laina  female  26.0       0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0       1
# 4                             Allen, Mr. William Henry    male  35.0       0
# ...

# %%
df4 = df.drop(['First_Name'],axis=1)

# %%
df4
# Out:
#      Passenger_Id  Survived  P_Class     Sex   Age  Sib_Sp  Parch  \
# 0               1         0        3    male  22.0       1      0
# 1               2         1        1  female  38.0       1      0
# 2               3         1        3  female  26.0       0      0
# 3               4         1        1  female  35.0       1      0
# 4               5         0        3    male  35.0       0      0
# ..            ...       ...      ...     ...   ...     ...    ...
# 886           887         0        2    male  27.0       0      0
# 887           888         1        1  female  19.0       0      0
# 888           889         0        3  female   NaN       1      2
# 889           890         1        1    male  26.0       0      0
# 890           891         0        3    male  32.0       0      0
#
#                Ticket     Fare Cabin Embarked  Fare2  random
# 0           A/5 21171   7.2500   NaN        S    7.0       8
# ...

# %%
df.drop(range(5),axis=0)
# Out:
#      Passenger_Id  Survived  P_Class  \
# 5               6         0        3
# 6               7         0        1
# 7               8         0        3
# 8               9         1        3
# 9              10         1        2
# ..            ...       ...      ...
# 886           887         0        2
# 887           888         1        1
# 888           889         0        3
# 889           890         1        1
# 890           891         0        3
#
#                                             First_Name     Sex   Age  Sib_Sp  \
# 5                                     Moran, Mr. James    male   NaN       0
# 6                              McCarthy, Mr. Timothy J    male  54.0       0
# 7                       Palsson, Master. Gosta Leonard    male   2.0       3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0       0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0       1
# ...
