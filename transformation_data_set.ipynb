# %%
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.Sex.value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.Sex.isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %%
df.Sex.isna().sum()
# Out:
# 0

# %%
df.Age.isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df.Age.isna().sum()
# Out:
# 177

# %%
pf.Categorical(df.Sex)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 pf.Categorical(df.Sex)
#
# NameError: name 'pf' is not defined

# %%
pd.Categorical(df.Sex)
# Out:
# ['male', 'female', 'female', 'female', 'male', ..., 'male', 'female', 'female', 'male', 'male']
# Length: 891
# Categories (2, object): ['female', 'male']

# %%
df['Gender'] = pd.Categorical(df.Sex)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# ...

# %%
df.memory_usege()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df.memory_usege()
#
# File ~\Desktop\jupyter\venv\lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'memory_usege'

# %%
df.memory_usage()
# Out:
# Index           128
# PassengerId    7128
# Survived       7128
# Pclass         7128
# Name           7128
# Sex            7128
# Age            7128
# SibSp          7128
# Parch          7128
# Ticket         7128
# Fare           7128
# Cabin          7128
# Embarked       7128
# Gender         1015
# dtype: int64

# %%
import random

# %%
random.choices(['Very Low'],'Low','Medium','High','Very High',k=891)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 random.choices(['Very Low'],'Low','Medium','High','Very High',k=891)
#
# TypeError: Random.choices() takes from 2 to 3 positional arguments but 6 positional arguments (and 1 keyword-only argument) were given

# %%
random.choices(['Very Low','Low','Medium','High','Very High'],k=891)
# Out:
# ['Low',
#  'Low',
#  'High',
#  'Very Low',
#  'Low',
#  'Very High',
#  'Medium',
#  'Low',
#  'Very High',
#  'Very Low',
#  'Very High',
#  'Low',
#  'Very High',
#  'High',
#  'Medium',
#  'Low',
#  'Very Low',
#  'Medium',
#  'Medium',
#  'High',
#  'Medium',
#  'Low',
#  'Medium',
#  'Medium',
#  'Medium',
#  'Very High',
#  'Medium',
#  'Very Low',
#  'Very Low',
#  'Very Low',
#  'Very High',
#  'Very Low',
#  'High',
#  'Very High',
#  'High',
#  'Low',
#  'High',
#  'High',
#  'Very High',
#  'Very High',
#  'High',
#  'High',
#  'Low',
#  'Low',
#  'Low',
#  'Very High',
#  'Medium',
#  'Very Low',
#  'Low',
#  'Very Low',
#  'Very Low',
#  'High',
#  'Medium',
#  'Very High',
#  'Low',
#  'Very Low',
#  'Medium',
#  'Very Low',
#  'Very Low',
#  'Low',
#  'Low',
#  'Very High',
#  'Medium',
#  'Very Low',
#  'Medium',
#  'High',
#  'Low',
#  'Medium',
#  'Low',
#  'Very Low',
#  'Very Low',
#  'High',
#  'Very High',
#  'Low',
#  'Low',
#  'High',
#  'Very Low',
# ...

# %%
pd.Series(random.choices(['Very Low','Low','Medium','High','Very High'],k=891))
# Out:
# 0          High
# 1          High
# 2        Medium
# 3      Very Low
# 4           Low
#          ...
# 886        High
# 887        High
# 888    Very Low
# 889        High
# 890         Low
# Length: 891, dtype: object

# %%
df['Score'] = pd.Series(random.choices(['Very Low','Low','Medium','High','Very High'],k=891))

# %%
df.head
# Out:
# <bound method NDFrame.head of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender      Score
# 0      0         A/5 21171   7.2500   NaN        S    male  Very High
# 1      0          PC 17599  71.2833   C85        C  female  Very High
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female     Medium
# ...

# %%
df.dtypes
# Out:
# PassengerId       int64
# Survived          int64
# Pclass            int64
# Name             object
# Sex              object
# Age             float64
# SibSp             int64
# Parch             int64
# Ticket           object
# Fare            float64
# Cabin            object
# Embarked         object
# Gender         category
# Score            object
# dtype: object

# %%
pd.Categorical(df.Score)
# Out:
# ['Very High', 'Very High', 'Medium', 'Very Low', 'High', ..., 'High', 'Low', 'Very High', 'Low', 'Low']
# Length: 891
# Categories (5, object): ['High', 'Low', 'Medium', 'Very High', 'Very Low']

# %%
pd.Categorical(df.Score,categories=['Very Low','Low','Medium','High','Very High'],ordered=True)
# Out:
# ['Very High', 'Very High', 'Medium', 'Very Low', 'High', ..., 'High', 'Low', 'Very High', 'Low', 'Low']
# Length: 891
# Categories (5, object): ['Very Low' < 'Low' < 'Medium' < 'High' < 'Very High']

# %%
df['Score2'] = pd.Categorical(df.Score,categories=['Very Low','Low','Medium','High','Very High'],ordered=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.Score2>'Medium'
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Score2, Length: 891, dtype: bool

# %%
sum(df.Score2>'Medium')
# Out:
# 347

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender      Score  \
# 0      0         A/5 21171   7.2500   NaN        S    male  Very High
# 1      0          PC 17599  71.2833   C85        C  female  Very High
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female     Medium
# ...

# %%
df.Age.min()
# Out:
# 0.42

# %%
df.Age.max()
# Out:
# 80.0

# %%
pd.cut(df.Age,bins = [0.4,10,20,30,40,80], labels = ['Very Low','Low','Medium','High','Very High')
# Out:
#   Cell In[32], line 1
#     pd.cut(df.Age,bins = [0.4,10,20,30,40,80], labels = ['Very Low','Low','Medium','High','Very High')
#                                                                                                      ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
pd.cut(df.Age,bins = [0.4,10,20,30,40,80], labels = ['Very Low','Low','Medium','High','Very High'])
# Out:
# 0      Medium
# 1        High
# 2      Medium
# 3        High
# 4        High
#         ...
# 886    Medium
# 887       Low
# 888       NaN
# 889    Medium
# 890      High
# Name: Age, Length: 891, dtype: category
# Categories (5, object): ['Very Low' < 'Low' < 'Medium' < 'High' < 'Very High']

# %%
df['cat_sa;ary'] = pd.cut(df.Age,bins = [0.4,10,20,30,40,80], labels = ['Very Low','Low','Medium','High','Very High'])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['salary'] = pd.cut(df.Age,bins = [0.4,10,20,30,40,80], labels = ['Very Low','Low','Medium','High','Very High'])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.memory_usage()
# Out:
# Index           128
# PassengerId    7128
# Survived       7128
# Pclass         7128
# Name           7128
# Sex            7128
# Age            7128
# SibSp          7128
# Parch          7128
# Ticket         7128
# Fare           7128
# Cabin          7128
# Embarked       7128
# Gender         1015
# Score          7128
# Score2         1103
# cat_sa;ary     1103
# salary         1103
# dtype: int64
